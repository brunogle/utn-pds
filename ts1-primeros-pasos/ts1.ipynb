# %% [markdown]
# # Procesamiento Digital de Señales - 2do Cuatrimestre 2025
#
# ## Trabajo Semanal 1 - Primeros Pasos en la Simulación
#
# **Alumno**: Bruno Glecer
#
# **Profesor**: Dr. Mariano Llamedo Soria
#
# ### Consigna
#
# En este primer trabajo comenzaremos por diseñar un generador de señales que utilizaremos en las primeras simulaciones que hagamos. La primer tarea consistirá en programar una función que genere señales senoidales y que permita parametrizar:
#
# - la amplitud máxima de la senoidal (volts)
# - su valor medio (volts)
# - la frecuencia (Hz)
# - la fase (radianes)
# - la cantidad de muestras digitalizada por el ADC (# muestras)
# - la frecuencia de muestreo del ADC.
#
# es decir que la función que uds armen debería admitir se llamada de la siguiente manera
#
# tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs)

# %% [markdown]
# ### Resolución

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mi_funcion_sen(nn, fs, vmax=1, dc=0, ff=1, ph=0):
    tt = np.linspace(0, nn/fs, num=nn)
    xx = vmax*np.sin(2*np.pi*ff*tt + ph) + dc
    return tt, xx

# %% [markdown]
# ### Ejemplos

# %%
tt, xx = mi_funcion_sen(1000, 1000, ff=5, vmax=2, dc=10, ph=np.pi/2)

plt.plot(tt,xx)
plt.grid()
plt.show()

# %%
tt, xx = mi_funcion_sen(40, 20)

plt.scatter(tt,xx)
plt.grid()
plt.show()
